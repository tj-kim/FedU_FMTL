# %%
cd /home/tkim/Academics/FedU_FMTL/
# Out:
# /home/tkim/Academics/FedU_FMTL

# %%
from utils.model_utils import *

# %%
dataset = 'human_activity'
data = read_data(dataset)

# %%
# ID, null, trainset, testset.
data[4]['f_00000']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-f5349a386c69> in <module>
# ----> 1 data[4]['f_00000']
#
# IndexError: tuple index out of range
